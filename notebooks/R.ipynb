# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-pc-linux-gnu"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "linux-gnu"
#
# $system
# [1] "x86_64, linux-gnu"
#
# $status
# [1] ""
#
# $major
# [1] "3"
#
# $minor
# [1] "4.4"
#
# $year
# [1] "2018"
#
# $month
# [1] "03"
#
# $day
# [1] "15"
#
# $`svn rev`
# [1] "74408"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 3.4.4 (2018-03-15)"
#
# $nickname
# [1] "Someone to Lean On"
